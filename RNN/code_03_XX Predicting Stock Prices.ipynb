# %% [markdown]
# In this example, we will predict stock prices for the next day, based on the time series patterns observed for the previous days.
#
#
#
#
# ## 03.01. Setup Environment
#
# Please make sure that the setup environment is executed once successfully, before attempting to use any of the exercise files in this course.

# %%
# !pip install keras
# !pip install tensorflow
# !pip install pandas
# !pip install matplotlib
# !pip install sklearn
# Out:
# Requirement already satisfied: keras in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: tensorflow in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: numpy>=1.20 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (0.25.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: flatbuffers>=1.12 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (3.20.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: libclang>=9.0.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: h5py>=2.9.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: setuptools in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (61.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.1.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Requirement already satisfied: pandas in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: six>=1.5 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: numpy>=1.14.6 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.22.3)
# Requirement already satisfied: joblib>=0.11 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/linkedin/opt/anaconda3/envs/rnn/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.1.0)

# %% [markdown]
# ## 03.02.Load & Split Stock Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(1)

#Load the Meta stock price data from CSV
prices = pd.read_csv('FB-stock-prices.csv')

#Review loaded data
print(prices.dtypes)
prices.head()
# Out:
# Date     object
# Price     int64
# dtype: object
#        Date  Price
# 0  1/4/2021    269
# 1  1/5/2021    271
# 2  1/6/2021    263
# 3  1/7/2021    269
# 4  1/8/2021    268

# %%
# Plot the data to visualize the stock price

plt.figure(figsize=(20,10)).suptitle("Daily FB Price", fontsize=20)
plt.plot(prices["Price"])
plt.show()

# %% [markdown]
# ### Split Data

# %%
from sklearn.preprocessing import StandardScaler

# Scale the Data
scaler = StandardScaler()
scaled_prices=scaler.fit_transform(prices[["Price"]].values)

#Split data into Training and Test sets
total_size = len(scaled_prices)

#Test dataset size
test_size = 50

#Training dataset size
train_size = total_size - test_size
print(train_size, test_size)

training_prices = scaled_prices[0:train_size,:]
test_prices = scaled_prices[train_size:,:]

print(training_prices.shape, test_prices.shape)
# Out:
# 201 50
# (201, 1) (50, 1)

# %% [markdown]
# ## 03.03 Create Dataset for RNN

# %%
#Prepare RNN Dataset. 
#Each data point (X) is linked to the previous data points of size=lookback
#The predicted value (Y) is the next point

def create_rnn_dataset(data, lookback=1):
    
    data_x, data_y = [], []
    for i in range(len(data)- lookback -1):
            #All points from this point, looking backwards upto lookback
            a = data[i:(i+ lookback), 0]
            data_x.append(a)
            #The next point
            data_y.append(data[i + lookback, 0])
    return np.array(data_x), np.array(data_y)

#lookback for 25 previous days
lookback=25

#Create X and Y for training
train_req_x, train_req_y = create_rnn_dataset(training_prices,lookback)
print("Train X has",len(train_req_x), "Samples of ",train_req_x[0])
print("Train Y",train_req_y[0])

#Reshape for use with RNN
train_req_x = np.reshape(train_req_x, 
                         (train_req_x.shape[0],1, train_req_x.shape[1]))

print("Shapes of X, Y: ",train_req_x.shape, train_req_y.shape)
print("New Train X has",len(train_req_x), "Samples of ",train_req_x[0])
# Out:
# Train X has 175 Samples of  [-1.49673154 -1.4393189  -1.66896946 -1.49673154 -1.52543786 -1.84120738
#  -2.01344531 -1.98473899 -2.15697691 -2.01344531 -1.7263821  -1.55414418
#  -1.38190626 -1.32449362 -1.23837465 -1.12354937 -1.41061258 -1.61155682
#  -1.81250106 -1.69767578 -1.55414418 -1.55414418 -1.5828505  -1.52543786
#  -1.55414418]
# Train Y -1.4967315390399443
# Shapes of X, Y:  (175, 1, 25) (175,)
# New Train X has 175 Samples of  [[-1.49673154 -1.4393189  -1.66896946 -1.49673154 -1.52543786 -1.84120738
#   -2.01344531 -1.98473899 -2.15697691 -2.01344531 -1.7263821  -1.55414418
#   -1.38190626 -1.32449362 -1.23837465 -1.12354937 -1.41061258 -1.61155682
#   -1.81250106 -1.69767578 -1.55414418 -1.55414418 -1.5828505  -1.52543786
#   -1.55414418]]

# %% [markdown]
# ## 03.04 Build the RNN Model

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Input
import tensorflow as tf

tf.random.set_seed(3)

#Create a Keras Model
price_model=Sequential()

# Add Input layer with specified input_shape
price_model.add(Input(shape=(1, lookback)))

#Add Simple RNN layer with 32 nodes
price_model.add(SimpleRNN(32))
#Add a Dense layer at the end for output
price_model.add(Dense(1))

#Compile with Adam Optimizer. Optimize for minimum mean square error
price_model.compile(loss="mean_squared_error",
                 optimizer="adam",
                 metrics=["mse"])

#Print model summary
price_model.summary()

#Train the model
price_model.fit(train_req_x, train_req_y, 
             epochs=5, batch_size=1, verbose=1)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 32)             │         1,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,889 (7.38 KB)
#  Trainable params: 1,889 (7.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.1479 - mse: 0.1479
# Epoch 2/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 0.0634 - mse: 0.0634
# Epoch 3/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - loss: 0.0462 - mse: 0.0462
# Epoch 4/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - loss: 0.0371 - mse: 0.0371
# Epoch 5/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - loss: 0.0321 - mse: 0.0321

# %% [markdown]
# ## 03.05. Test the Model

# %%
#Preprocess the test dataset, the same way training set is processed
test_req_x, test_req_y = create_rnn_dataset(test_prices,lookback)

print(test_req_x.shape, test_req_y.shape)

test_req_x = np.reshape(test_req_x, 
                         (test_req_x.shape[0],1, test_req_x.shape[1]))

#Evaluate the model
price_model.evaluate(test_req_x, test_req_y, verbose=1)

#Predict on the test dataset
predict_on_test = price_model.predict(test_req_x)

#Inverse the scaling to view results
predict_on_test = scaler.inverse_transform(predict_on_test)
# Out:
# (24, 25) (24,)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0550 - mse: 0.0550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %% [markdown]
# ## Visualize the Results

# %%
#Extract original test values that map to the same dates on the predicted test values
orig_test_values = prices[["Price"]].loc[total_size-len(predict_on_test):]
orig_test_values.reset_index(drop=True, inplace=True)

plt.figure(figsize=(20,10)).suptitle("Plot Predictions for Original Test Data", fontsize=20)
plt.plot(orig_test_values, label="Original Price")
plt.plot(predict_on_test, label="Predicted Price")
plt.legend()
plt.show()

# %% [markdown]
# Accuracy can be increased by having more data points, creating more lookback and trying other RNN models

# %% [markdown]
# ### Predictions

# %%
#Previous prices
previous_prices = np.array([325,335,340,341,342,
                            325,329,316,312,317,
                            324,330,328,332,336,
                            341,339,335,328,328,
                            341,348,343,341,339])

#Scale
scaled_prices = scaler.transform(previous_prices.reshape(-1, 1))
#Reshape
model_input = np.reshape(scaled_prices, 
                         (scaled_prices.shape[1],1, scaled_prices.shape[0]))

#predictions
prediction = price_model.predict(model_input)

#scale back
norm_prediction = scaler.inverse_transform(prediction)

print("The predicted Stock price is :", norm_prediction[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# The predicted Stock price is : 337.17758
